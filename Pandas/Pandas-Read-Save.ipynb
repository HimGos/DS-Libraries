# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Reading next sheet of the excel file....

# %%
pd.read_excel(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\Attribute DataSet.xlsx' , sheet_name= 'Sheet2')
# Out:
#    asdasd    fhg     w
# 0   sadsd  dfgdf     s
# 1      sd      g   xcv
# 2  asdasd    fgh   bvb
# 3    sdas      x   xcv
# 4      dd    fgh  xcvx
# 5    asdd    gfh    jh
# 6   sadsd    fgh    fg
# 7      gd    fgh     x
# 8       h    fgh   xcv

# %% [markdown]
# #

# %% [markdown]
# ### Setting custom header of the above file..

# %%
pd.read_excel(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\Attribute DataSet.xlsx' , sheet_name= 'Sheet2' , header = None)
# Out:
#         0      1     2
# 0  asdasd    fhg     w
# 1   sadsd  dfgdf     s
# 2      sd      g   xcv
# 3  asdasd    fgh   bvb
# 4    sdas      x   xcv
# 5      dd    fgh  xcvx
# 6    asdd    gfh    jh
# 7   sadsd    fgh    fg
# 8      gd    fgh     x
# 9       h    fgh   xcv

# %%
pd.read_excel(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\Attribute DataSet.xlsx' , sheet_name= 'Sheet2' , 
              header = None , names =['A', 'B', 'C'])
# Out:
#         A      B     C
# 0  asdasd    fhg     w
# 1   sadsd  dfgdf     s
# 2      sd      g   xcv
# 3  asdasd    fgh   bvb
# 4    sdas      x   xcv
# 5      dd    fgh  xcvx
# 6    asdd    gfh    jh
# 7   sadsd    fgh    fg
# 8      gd    fgh     x
# 9       h    fgh   xcv

# %%
pd.read_excel(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\Attribute DataSet.xlsx' , sheet_name= 'Sheet2'
              , names =['A', 'B', 'C'])
# Out:
#         A      B     C
# 0   sadsd  dfgdf     s
# 1      sd      g   xcv
# 2  asdasd    fgh   bvb
# 3    sdas      x   xcv
# 4      dd    fgh  xcvx
# 5    asdd    gfh    jh
# 6   sadsd    fgh    fg
# 7      gd    fgh     x
# 8       h    fgh   xcv

# %%
# Here not using header = None , ate our first row.

# %% [markdown]
# #

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %% [markdown]
# ### To check first few records, use head()  ... by default head() = first 5 .. we can mention other number in it

# %%
df.head(4)
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
#
#   waiseline    Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon     ruffles       animal               1
# 1   natural  microfiber        NaN     ruffles       animal               0
# 2   natural    polyster        NaN         NaN        print               0
# 3   natural        silk    chiffon  embroidary        print               1

# %% [markdown]
# ### To check last few records, use tail() ... by default tail() = last 5 .. we can mention other number in it

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(3)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 497    empire   cotton         NaN       lace        solid               1
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %% [markdown]
# #

# %% [markdown]
# ### Reading CSV format file

# %%
pd.read_csv(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\haberman.csv' , 
            header = None, names=['Age', 'Patient Year of Operation', 'No. of Positive', 'Survival Status'])
# Out:
#      Age  Patient Year of Operation  No. of Positive  Survival Status
# 0     30                         64                1                1
# 1     30                         62                3                1
# 2     30                         65                0                1
# 3     31                         59                2                1
# 4     31                         65                4                1
# ..   ...                        ...              ...              ...
# 301   75                         62                1                1
# 302   76                         67                0                1
# 303   77                         65                3                1
# 304   78                         65                1                2
# 305   83                         58                2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\haberman2.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 300   75@62@1@1
# 301   76@67@0@1
# 302   77@65@3@1
# 303   78@65@1@2
# 304   83@58@2@2
#
# [305 rows x 1 columns]

# %% [markdown]
# ### In case of messed up data like this then we need to use parameter -> sep

# %%
pd.read_csv(r'C:\Users\Himz\Downloads\data fsds -20220725T010627Z-001\data fsds\haberman2.csv', sep="@")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %% [markdown]
# #

# %% [markdown]
# ### Fetching Someone's CSV file from their GitHub  (raw content)

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %% [markdown]
# #

# %% [markdown]
# ### Reading a table given on website like basketball website

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
a = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %% [markdown]
# #

# %% [markdown]
# ### Reading JSON format data

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
a = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'draft', 'pull_request'],
#       dtype='object')

# %%
a['user']
# Out:
# 0     {'login': 'windowshopr', 'id': 40477419, 'node...
# 1     {'login': 'bzhaoopenstack', 'id': 11386522, 'n...
# 2     {'login': 'PriestlyAdejo', 'id': 108146732, 'n...
# 3     {'login': 'PriestlyAdejo', 'id': 108146732, 'n...
# 4     {'login': 'GivyBoy', 'id': 58392771, 'node_id'...
# 5     {'login': 'mattB1989', 'id': 13086632, 'node_i...
# 6     {'login': 'bherwerth', 'id': 108834862, 'node_...
# 7     {'login': 'ravindrabajpai', 'id': 1445512, 'no...
# 8     {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 9     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 10    {'login': 'shourya5', 'id': 73142986, 'node_id...
# 11    {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 12    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 13    {'login': 'attack68', 'id': 24256554, 'node_id...
# 14    {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 15    {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 16    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# ...

# %% [markdown]
# #

# %% [markdown]
# ### Converting Previous Excel into JSON in order to make it ready for MongoDB

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_json('pandas-first-class.json')

# %%
pwd
# Out:
# 'C:\\Users\\Himz'

# %% [markdown]
# #

# %% [markdown]
# ### Saving the data

# %%
# All the to_  functions allow us to save data in chosen format

# %%
df.to_csv("D://pandas-first-clas.csv")

# %%
df.to_csv("D://pandas-first-clas123.csv", sep='#')

# %%
df.to_csv("D://pandas-first-clas-noindex.csv", index=False)

# since pandas by default indexed our data, so during save also it placed those indices. So we can remove them this way.
