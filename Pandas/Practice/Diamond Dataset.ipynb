# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')

# %% [markdown]
# ##### 1. Write a Pandas program to read a csv file from a specified source and print the first 5 rows.

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ##### 2. Write a Pandas program to read a dataset from diamonds DataFrame and modify the default columns values and print the first 6 rows.

# %%
df[['carat', 'cut', 'x', 'y']].head(6)
# Out:
#    carat        cut     x     y
# 0   0.23      Ideal  3.95  3.98
# 1   0.21    Premium  3.89  3.84
# 2   0.23       Good  4.05  4.07
# 3   0.29    Premium  4.20  4.23
# 4   0.31       Good  4.34  4.35
# 5   0.24  Very Good  3.94  3.96

# %% [markdown]
# ##### 3. Write a Pandas program to select a series from diamonds DataFrame. Print the content of the series.

# %%
df['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %% [markdown]
# ##### 4. Write a Pandas program to create a new 'Quality -color' Series (use bracket notation to define the Series name) of the diamonds DataFrame.

# %%
df['quality_color'] = df['cut'] + ', ' + df['color']
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   quality_color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %% [markdown]
# ##### 5. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe

# %%
df.shape
df.dtypes
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# quality_color     object
# dtype: object

# %% [markdown]
# ##### 6. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

# %%
filt = df.dtypes == 'object'
df.dtypes[filt]
# Out:
# cut              object
# color            object
# clarity          object
# quality_color    object
# dtype: object

# %% [markdown]
# ##### 7. Write a Pandas program to rename two of the columns of the diamonds Dataframe.

# %%
df.rename(columns={'color':'colour', 'price':'amount'}).head()
# Out:
#    carat      cut colour clarity  depth  table  amount     x     y     z  \
# 0   0.23    Ideal      E     SI2   61.5   55.0     326  3.95  3.98  2.43
# 1   0.21  Premium      E     SI1   59.8   61.0     326  3.89  3.84  2.31
# 2   0.23     Good      E     VS1   56.9   65.0     327  4.05  4.07  2.31
# 3   0.29  Premium      I     VS2   62.4   58.0     334  4.20  4.23  2.63
# 4   0.31     Good      J     SI2   63.3   58.0     335  4.34  4.35  2.75
#
#   quality_color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %% [markdown]
# ##### 8. Write a Pandas program to rename all the columns of the diamonds Dataframe.

# %%
df.rename(columns={'carat':'carrot', 'cut':'quality', 'color':'colour', 'clarity':'clear', 'depth':'deep'
                  , 'table':'content', 'price':'amount'}).head()
# Out:
#    carrot  quality colour clear  deep  content  amount     x     y     z  \
# 0    0.23    Ideal      E   SI2  61.5     55.0     326  3.95  3.98  2.43
# 1    0.21  Premium      E   SI1  59.8     61.0     326  3.89  3.84  2.31
# 2    0.23     Good      E   VS1  56.9     65.0     327  4.05  4.07  2.31
# 3    0.29  Premium      I   VS2  62.4     58.0     334  4.20  4.23  2.63
# 4    0.31     Good      J   SI2  63.3     58.0     335  4.34  4.35  2.75
#
#   quality_color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %% [markdown]
# ##### 9. Write a Pandas program to remove the second column of the diamonds Dataframe.

# %%
df.drop(columns='cut').head()
# Out:
#    carat color clarity  depth  table  price     x     y     z quality_color
# 0   0.23     E     SI2   61.5   55.0    326  3.95  3.98  2.43      Ideal, E
# 1   0.21     E     SI1   59.8   61.0    326  3.89  3.84  2.31    Premium, E
# 2   0.23     E     VS1   56.9   65.0    327  4.05  4.07  2.31       Good, E
# 3   0.29     I     VS2   62.4   58.0    334  4.20  4.23  2.63    Premium, I
# 4   0.31     J     SI2   63.3   58.0    335  4.34  4.35  2.75       Good, J

# %% [markdown]
# ##### 10. Write a Pandas program to remove multiple columns at once of the diamonds Dataframe.

# %%
df.drop(columns=['cut', 'color']).head(2)
# Out:
#    carat clarity  depth  table  price     x     y     z quality_color
# 0   0.23     SI2   61.5   55.0    326  3.95  3.98  2.43      Ideal, E
# 1   0.21     SI1   59.8   61.0    326  3.89  3.84  2.31    Premium, E

# %% [markdown]
# ##### 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe.

# %%
df.drop([0,1]).head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   quality_color
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %% [markdown]
# ##### 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
df['cut'].sort_values()
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %% [markdown]
# ##### 13. Write a Pandas program to sort the 'price' Series in descending order (returns a Series) of diamonds Dataframe.

# %%
df['price'].sort_values(ascending=False)
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 4          335
# 3          334
# 2          327
# 1          326
# 0          326
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# ##### 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
df.sort_values('carat').head()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 31593    0.2  Premium     E     VS2   61.1   59.0    367  3.81  3.78  2.32
# 31597    0.2    Ideal     D     VS2   61.5   57.0    367  3.81  3.77  2.33
# 31596    0.2  Premium     F     VS2   62.6   59.0    367  3.73  3.71  2.33
# 31595    0.2    Ideal     E     VS2   59.7   55.0    367  3.86  3.84  2.30
# 31594    0.2  Premium     E     VS2   59.7   62.0    367  3.84  3.80  2.28
#
#       quality_color
# 31593    Premium, E
# 31597      Ideal, D
# 31596    Premium, F
# 31595      Ideal, E
# 31594    Premium, E

# %%
df.sort_values('carat',ascending=False).head()
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z  \
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
#
#       quality_color
# 27415       Fair, J
# 27630       Fair, J
# 27130       Fair, H
# 25999    Premium, J
# 25998    Premium, I

# %% [markdown]
# ##### 15. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
filt = df['carat'] < 0.3
df.loc[filt].head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
#
#   quality_color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 5  Very Good, J

# %% [markdown]
# ##### 16. Write a Pandas program to convert a python list to pandas series.

# %%
l = [1,2,3,4,45,5,6,7,8,8]
s = pd.Series(l)
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### 17. Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
filt = (df['x'] > 5) & (df['y'] > 5) & (df['z'] > 5)
df.loc[filt].head()
# Out:
#        carat   cut color clarity  depth  table  price     x     y     z  \
# 11778   1.83  Fair     J      I1   70.0   58.0   5083  7.34  7.28  5.12
# 13002   2.14  Fair     J      I1   69.4   57.0   5405  7.74  7.70  5.36
# 13118   2.15  Fair     J      I1   65.5   57.0   5430  8.01  7.95  5.23
# 13562   1.96  Fair     F      I1   66.6   60.0   5554  7.59  7.56  5.04
# 13757   2.22  Fair     J      I1   66.7   56.0   5607  8.04  8.02  5.36
#
#       quality_color
# 11778       Fair, J
# 13002       Fair, J
# 13118       Fair, J
# 13562       Fair, F
# 13757       Fair, J

# %% [markdown]
# ##### 18. Write a Pandas program to find the diamonds that are either Premium or Ideal.

# %%
filt = (df['cut'] == 'Premium') | (df['cut'] == 'Ideal')
df.loc[filt].head()
# Out:
#     carat      cut color clarity  depth  table  price     x     y     z  \
# 0    0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3    0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11   0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12   0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
#
#    quality_color
# 0       Ideal, E
# 1     Premium, E
# 3     Premium, I
# 11      Ideal, J
# 12    Premium, F

# %% [markdown]
# ##### 19. Write a Pandas program to find the diamonds that are with a Fair or Good or Premium.

# %%
filt = (df['cut'] == 'Premium') | (df['cut'] == 'Fair') | (df['cut'] == 'Good')
df.loc[filt].head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 8   0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
#
#   quality_color
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J
# 8       Fair, E

# %% [markdown]
# ##### 20. Write a Pandas program to display all column labels of diamonds DataFrame.

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'quality_color'],
#       dtype='object')

# %% [markdown]
# ##### 21. Write a Pandas program to read only a subset of 3 rows from diamonds DataFrame.

# %%
test = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv', nrows=3)
test
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5     55    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8     61    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9     65    327  4.05  4.07  2.31

# %% [markdown]
# ##### 22. Write a Pandas program to iterate through diamonds DataFrame.

# %%
for i,j in test.iterrows():
    print(i,j.carat, j.cut)
# Out:
# 0 0.23 Ideal
# 1 0.21 Premium
# 2 0.23 Good

# %% [markdown]
# ##### 23. Write a Pandas program to drop all non-numeric columns from diamonds DataFrame.

# %%
df.select_dtypes(exclude='object').head(3)
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31

# %% [markdown]
# ##### 24. Write a Pandas program to include only numeric columns in the diamonds DataFrame.

# %%
df.select_dtypes('number').head(3)
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31

# %% [markdown]
# ##### 25. Write a Pandas program to pass a list of data types to only describe certain types of diamonds DataFrame.

# %%
df.describe(include=['object','int64'])
# Out:
#           cut  color clarity         price quality_color
# count   53940  53940   53940  53940.000000         53940
# unique      5      7       8           NaN            35
# top     Ideal      G     SI1           NaN      Ideal, G
# freq    21551  11292   13065           NaN          4884
# mean      NaN    NaN     NaN   3932.799722           NaN
# std       NaN    NaN     NaN   3989.439738           NaN
# min       NaN    NaN     NaN    326.000000           NaN
# 25%       NaN    NaN     NaN    950.000000           NaN
# 50%       NaN    NaN     NaN   2401.000000           NaN
# 75%       NaN    NaN     NaN   5324.250000           NaN
# max       NaN    NaN     NaN  18823.000000           NaN

# %% [markdown]
# ##### 26. Write a Pandas program to calculate the mean of each numeric column of diamonds DataFrame.

# %%
df.select_dtypes('number').mean()
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %% [markdown]
# ##### 27. Write a Pandas program to calculate the mean of each row of diamonds DataFrame.

# %%
df.mean(axis=1).head()
# Out:
# C:\Users\Himz\AppData\Local\Temp\ipykernel_25396\3248753150.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=1).head()
# 0    64.727143
# 1    65.292857
# 2    65.651429
# 3    66.535714
# 4    66.864286
# dtype: float64

# %% [markdown]
# ##### 28. Write a Pandas program to calculate the mean of price for each cut of diamonds DataFrame.

# %%
cut_group = df.groupby('cut')
cut_group['price'].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# ##### 29. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
cut_count = cut_group['price'].count()

cut_min = cut_group['price'].min()

cut_max = cut_group['price'].max()

df_cut = pd.concat({'count':cut_count, 'min':cut_min, 'max':cut_max}, axis=1)
df_cut
# Out:
#            count  min    max
# cut
# Fair        1610  337  18574
# Good        4906  327  18788
# Ideal      21551  326  18806
# Premium    13791  326  18823
# Very Good  12082  336  18818

# %% [markdown]
# ##### 30. Write a Pandas program to create a side-by-side bar plot of the diamonds DataFrame.

# %%
df_cut.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='cut'>

# %% [markdown]
# ##### 31. Write a Pandas program to count how many times each value in cut series of diamonds DataFrame occurs.

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# ##### 32. Write a Pandas program to display percentages of each value of cut series occurs in diamonds DataFrame.

# %%
df['cut'].value_counts(normalize=True)*100
# Out:
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: cut, dtype: float64

# %% [markdown]
# ##### 33. Write a Pandas program to display the unique values in cut series of diamonds DataFrame.

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# ##### 34. Write a Pandas program to count the number of unique values in cut series of diamonds DataFrame.

# %%
df['cut'].nunique()
# Out:
# 5

# %% [markdown]
# ##### 35. Write a Pandas program to compute a cross-tabulation of two Series in diamonds DataFrame.

# %%
pd.crosstab(df['cut'], df['color'])
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %% [markdown]
# ##### 36. Write a Pandas program to calculate various summary statistics of cut series of diamonds DataFrame.

# %%
df['cut'].describe()
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %% [markdown]
# ##### 37. Write a Pandas program to create a histogram of the 'carat' Series (distribution of a numerical variable) of diamonds DataFrame.

# %%
df['carat'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ##### 38. Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut' series of diamonds DataFrame.

# %%
df['cut'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 39. Write a Pandas program to create a DataFrame of booleans (True if missing, False if not missing) from diamonds DataFrame.

# %%
df.isna().head()
# Out:
#    carat    cut  color  clarity  depth  table  price      x      y      z  \
# 0  False  False  False    False  False  False  False  False  False  False
# 1  False  False  False    False  False  False  False  False  False  False
# 2  False  False  False    False  False  False  False  False  False  False
# 3  False  False  False    False  False  False  False  False  False  False
# 4  False  False  False    False  False  False  False  False  False  False
#
#    quality_color
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %% [markdown]
# ##### 40. Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
df.isna().sum()
# Out:
# carat            0
# cut              0
# color            0
# clarity          0
# depth            0
# table            0
# price            0
# x                0
# y                0
# z                0
# quality_color    0
# dtype: int64

# %% [markdown]
# ##### 41. Write a Pandas program to check the number of rows and columns and drop those row if 'any' values are missing in a row of diamonds DataFrame.

# %%
df.dropna(how='any')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality_color
# 0          Ideal, E
# 1        Premium, E
# 2           Good, E
# 3        Premium, I
# 4           Good, J
# ...             ...
# 53935      Ideal, D
# 53936       Good, D
# 53937  Very Good, D
# 53938    Premium, H
# 53939      Ideal, D
#
# [53940 rows x 11 columns]

# %% [markdown]
# ##### 42. Write a Pandas program to drop a row if any or all values in a row are missing of diamonds DataFrame on two specific columns.

# %%
df.dropna(subset=['cut','price'], how='any')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality_color
# 0          Ideal, E
# 1        Premium, E
# 2           Good, E
# 3        Premium, I
# 4           Good, J
# ...             ...
# 53935      Ideal, D
# 53936       Good, D
# 53937  Very Good, D
# 53938    Premium, H
# 53939      Ideal, D
#
# [53940 rows x 11 columns]

# %% [markdown]
# ##### 43. Write a Pandas program to set an existing column as the index of diamonds DataFrame.

# %%
df.set_index('color').head()
# Out:
#        carat      cut clarity  depth  table  price     x     y     z  \
# color
# E       0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#       quality_color
# color
# E          Ideal, E
# E        Premium, E
# E           Good, E
# I        Premium, I
# J           Good, J

# %% [markdown]
# ##### 44. Write a Pandas program to set an existing column as the index of diamonds DataFrame and restore the index name, and move the index back to a column.

# %%
df.set_index('color',inplace=True)
df.index.name = 'color'
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z  \
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   quality_color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I
# 4       Good, J

# %% [markdown]
# ##### 45. Write a Pandas program to access a specified Series index and the Series values of diamonds DataFrame.

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df['cut'].value_counts().index
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
df['cut'].value_counts().values
# Out:
# array([21551, 13791, 12082,  4906,  1610], dtype=int64)

# %% [markdown]
# ##### 46. Write a Pandas program to sort a Series by its values and index of diamonds DataFrame.

# %%
df['cut'].value_counts().sort_index()
# Out:
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13791
# Very Good    12082
# Name: cut, dtype: int64

# %%
df['cut'].value_counts().sort_values()
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: cut, dtype: int64

# %% [markdown]
# ##### 47. Write a Pandas program to calculate the multiply of length, width and depth for each cut of diamonds DataFrame.

# %%
(df.x*df.y*df.z).head()
# Out:
# 0    38.202030
# 1    34.505856
# 2    38.076885
# 3    46.724580
# 4    51.917250
# dtype: float64

# %% [markdown]
# ##### 48. Write a Pandas program to concatenate the diamonds DataFrame with the 'color' Series.

# %%
pd.concat([df,df['color']],axis=1)
# Out:
#       color  carat        cut clarity  depth  table  price     x     y     z  \
# 0         E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1         E   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2         E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3         I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4         J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 53935     D   0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936     D   0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937     D   0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938     H   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939     D   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality_color color
# 0          Ideal, E     E
# 1        Premium, E     E
# 2           Good, E     E
# 3        Premium, I     I
# 4           Good, J     J
# ...             ...   ...
# 53935      Ideal, D     D
# 53936       Good, D     D
# 53937  Very Good, D     D
# 53938    Premium, H     H
# 53939      Ideal, D     D
#
# [53940 rows x 12 columns]

# %% [markdown]
# ##### 49. Write a Pandas program to read specified rows and all columns of diamonds DataFrame.

# %%
df.loc[[0,5]]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z  \
# 0     E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
#
#   quality_color
# 0      Ideal, E
# 5  Very Good, J

# %% [markdown]
# ##### 50. Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds DataFrame.

# %%
df.loc[[0,5,7]]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z  \
# 0     E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7     H   0.26  Very Good     SI1   61.9   55.0    337  4.07  4.11  2.53
#
#   quality_color
# 0      Ideal, E
# 5  Very Good, J
# 7  Very Good, H

# %% [markdown]
# ##### 51. Write a Pandas program to read rows 2 through 5 and all columns of diamonds DataFrame.

# %%
df.loc[2:5]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z  \
# 2     E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
#
#   quality_color
# 2       Good, E
# 3    Premium, I
# 4       Good, J
# 5  Very Good, J

# %% [markdown]
# ##### 52. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' and 'price' of diamonds DataFrame.

# %%
df.loc[0:2,['color', 'price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# ##### 53. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color' through 'price' (inclusive) of diamonds DataFrame.

# %%
df.loc[0:2,'color': 'price']
# Out:
#   color  carat      cut clarity  depth  table  price
# 0     E   0.23    Ideal     SI2   61.5   55.0    326
# 1     E   0.21  Premium     SI1   59.8   61.0    326
# 2     E   0.23     Good     VS1   56.9   65.0    327

# %% [markdown]
# ##### 54. Write a Pandas program to read rows in which the 'cut' is 'Premium', column 'color' of diamonds DataFrame.

# %%
filt = df['cut'] == 'Premium'
df.loc[filt, 'color']
# Out:
# 1        E
# 3        I
# 12       F
# 14       E
# 15       E
#         ..
# 53928    E
# 53930    E
# 53931    F
# 53934    D
# 53938    H
# Name: color, Length: 13791, dtype: object

# %% [markdown]
# ##### 55. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
df.iloc[[0,1],[0,3]]
# Out:
#   color clarity
# 0     E     SI2
# 1     E     SI1

# %% [markdown]
# ##### 56. Write a Pandas program to read rows in positions 0 through 4, columns in positions 1 through 4 of diamonds DataFrame.

# %%
df.iloc[0:4, 1:4]
# Out:
#    carat      cut clarity
# 0   0.23    Ideal     SI2
# 1   0.21  Premium     SI1
# 2   0.23     Good     VS1
# 3   0.29  Premium     VS2

# %% [markdown]
# ##### 57. Write a Pandas program to read rows in positions 0 through 4 (exclusive) and all columns of diamonds DataFrame.

# %%
df.iloc[0:4]
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z  \
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
#
#   quality_color
# 0      Ideal, E
# 1    Premium, E
# 2       Good, E
# 3    Premium, I

# %% [markdown]
# ##### 58. Write a Pandas program to read rows 2 through 5 (inclusive), columns in positions 0 through 2 (exclusive) of diamonds DataFrame.

# %%
df.iloc[2:6,0:2]
# Out:
#   color  carat
# 2     E   0.23
# 3     I   0.29
# 4     J   0.31
# 5     J   0.24

# %% [markdown]
# ##### 59. Write a Pandas program to print a concise summary of diamonds DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   color          53940 non-null  object
#  1   carat          53940 non-null  float64
#  2   cut            53940 non-null  object
#  3   clarity        53940 non-null  object
#  4   depth          53940 non-null  float64
#  5   table          53940 non-null  float64
#  6   price          53940 non-null  int64
#  7   x              53940 non-null  float64
#  8   y              53940 non-null  float64
#  9   z              53940 non-null  float64
#  10  quality_color  53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.5+ MB

# %% [markdown]
# ##### 60. Write a Pandas program to get the true memory usage by diamonds DataFrame

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   color          53940 non-null  object
#  1   carat          53940 non-null  float64
#  2   cut            53940 non-null  object
#  3   clarity        53940 non-null  object
#  4   depth          53940 non-null  float64
#  5   table          53940 non-null  float64
#  6   price          53940 non-null  int64
#  7   x              53940 non-null  float64
#  8   y              53940 non-null  float64
#  9   z              53940 non-null  float64
#  10  quality_color  53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 15.6 MB

# %% [markdown]
# ##### 61. Write a Pandas program to calculate the memory usage for each Series (in bytes) of diamonds DataFrame.

# %%
df.memory_usage(deep=True)
# Out:
# Index                128
# color            3128520
# carat             431520
# cut              3413674
# clarity          3242590
# depth             431520
# table             431520
# price             431520
# x                 431520
# y                 431520
# z                 431520
# quality_color    3575494
# dtype: int64

# %% [markdown]
# ##### 62. Write a Pandas program to get randomly sample rows from diamonds DataFrame.

# %%
df.sample(4)
# Out:
#       color  carat      cut clarity  depth  table  price     x     y     z  \
# 23347     G   0.30    Ideal     SI2   62.0   55.0    422  4.28  4.33  2.67
# 14589     G   1.00  Premium     VS2   61.0   59.0   5887  6.41  6.37  3.90
# 27118     I   2.35  Premium     SI2   59.9   58.0  17294  8.68  8.61  5.18
# 13862     H   1.15     Good     VS2   63.1   56.0   5646  6.62  6.70  4.20
#
#       quality_color
# 23347      Ideal, G
# 14589    Premium, G
# 27118    Premium, I
# 13862       Good, H

# %% [markdown]
# ##### 63. Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.

# %%
df.sample(frac=0.75).shape

df25 = df.sample(frac=0.25)

# %%
df25.shape
# Out:
# (13485, 11)

# %%
df.shape
# Out:
# (53940, 11)

# %% [markdown]
# ##### 64. Write a Pandas program to read the diamonds DataFrame and detect duplicate color.

# %%
df['color'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: color, Length: 53940, dtype: bool

# %% [markdown]
# ##### 65. Write a Pandas program to count the duplicate rows of diamonds DataFrame.

# %%
df.loc[df.duplicated() == True]
# Out:
#       color  carat    cut clarity  depth  table  price     x     y     z  \
# 1005      G   0.79  Ideal     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1006      G   0.79  Ideal     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1007      G   0.79  Ideal     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1008      G   0.79  Ideal     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 2025      E   1.52   Good      I1   57.3   58.0   3105  7.53  7.42  4.28
# ...     ...    ...    ...     ...    ...    ...    ...   ...   ...   ...
# 47969     D   0.52  Ideal     VS2   61.8   55.0   1919  5.19  5.16  3.20
# 49326     F   0.51  Ideal    VVS2   61.2   56.0   2093  5.17  5.19  3.17
# 49557     F   0.71   Good     SI2   64.1   60.0   2130  0.00  0.00  0.00
# 50079     F   0.51  Ideal    VVS2   61.2   56.0   2203  5.19  5.17  3.17
# 52861     E   0.50   Fair     VS2   79.0   73.0   2579  5.21  5.18  4.09
#
#       quality_color
# 1005       Ideal, G
# 1006       Ideal, G
# 1007       Ideal, G
# 1008       Ideal, G
# 2025        Good, E
# ...             ...
# 47969      Ideal, D
# 49326      Ideal, F
# 49557       Good, F
# 50079      Ideal, F
# 52861       Fair, E
#
# [146 rows x 11 columns]

# %%
df.duplicated().sum()
# Out:
# 146
